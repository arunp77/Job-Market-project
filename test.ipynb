# %%
import pandas as pd

# Define the file path
file_path = 'data/scraped_data/muse/csv/muse_scrapped_data.csv'

# Read the CSV file into a pandas DataFrame
df_muse = pd.read_csv(file_path)

# Display the first few rows of the DataFrame
df_muse.head()
# Out:
#                                            Job Title Company Name  \
# 0             Senior IT Enterprise Architect (w/m/d)      Siemens
# 1  Fahrleitungsmonteur (w/m/d) Fahrleitungs- und ...      Siemens
# 2                  (Junior) Business Analyst (f/m/d)      Siemens
# 3             Lead Data Science Engineer - Remote US      Siemens
# 4             IT Operations Analyst (w/m/d) Firewall      Siemens
#
#                             Location      Publication Date  \
# 0                    Berlin, Germany  2023-05-16T23:40:22Z
# 1                    Berlin, Germany  2023-01-24T00:42:10Z
# 2  Flexible / Remote, Warsaw, Poland  2023-05-18T23:39:44Z
# 3     Chicago, IL, Flexible / Remote  2023-05-16T23:40:21Z
# 4                    Munich, Germany  2023-01-28T23:37:48Z
#
#            Categories Experience Level  \
# 0     Computer and IT     Senior Level
# 1     Computer and IT        Mid Level
# 2  Data and Analytics        Mid Level
# 3  Data and Analytics     Senior Level
# 4     Computer and IT        Mid Level
#
#                                             Job Link Full/Part Time
# 0  https://www.themuse.com/jobs/siemens/senior-it...            NaN
# 1  https://www.themuse.com/jobs/siemens/fahrleitu...            NaN
# 2  https://www.themuse.com/jobs/siemens/junior-bu...      Full-time
# 3  https://www.themuse.com/jobs/siemens/lead-data...      Full-time
# 4  https://www.themuse.com/jobs/siemens/it-operat...      Full-time

# %%
# Define the file path
file_path = 'data/scraped_data/adjurna/csv/adzuna_scrapped_data.csv'

# Read the CSV file into a pandas DataFrame
df_adjurna = pd.read_csv(file_path)

# Display the first few rows of the DataFrame
df_adjurna.head()
# Out:
#                                     company  \
# 0  Süddeutsche Zeitung Digitale Medien GmbH
# 1           Technische Universität München
# 2                             O2 Telefónica
# 3                            Hoffmann Group
# 4                    ProSiebenSat.1 Careers
#
#                                                title  \
# 0                   Werkstudent (m/w/d) Data Science
# 1  Professor in Empirical Economics and Data Science
# 2  Duales Studium Data Science und Scientific Com...
# 3               Data Science Product Manager (m/f/d)
# 4                   Intern Data Science & AI (m/f/d)
#
#                    location  \
# 0  München, München (Kreis)
# 1   Altstadt-Lehel, München
# 2  München, München (Kreis)
# 3  München, München (Kreis)
# 4  München, München (Kreis)
#
#                                                 link  \
# 0  https://www.adzuna.de/land/ad/4559596995?se=AC...
# 1  https://www.adzuna.de/land/ad/4570297796?se=AC...
# 2  https://www.adzuna.de/land/ad/4570047587?se=AC...
# 3  https://www.adzuna.de/land/ad/4546865990?se=AC...
# 4  https://www.adzuna.de/land/ad/4548461379?se=AC...
#
#                   job_posted  \
# 0  2024-02-06 13:44:59+00:00
# 1  2024-02-15 17:42:47+00:00
# 2  2024-02-15 13:34:32+00:00
# 3  2024-01-27 13:21:18+00:00
# 4  2024-01-29 13:19:48+00:00
#
#                                             category  \
# 0  Aufgaben Profil Wir bieten Die Süddeutsche Zei...
# 1  The Technical University of Munich (TUM) invit...
# 2  Vertragsart: Vollzeit, befristet Standort: Tel...
# 3  More than 4,000 highly motivated employees in ...
# 4  Let's CreateMomentsThatMatter together ProSieb...
#
#                                           source description
# 0                    Sonstige/Allgemeine Stellen      Adzuna
# 1                                        Unknown      Adzuna
# 2                                        Unknown      Adzuna
# 3  Stellen aus Wissenschaft & Qualitätssicherung      Adzuna
# 4  Stellen aus Wissenschaft & Qualitätssicherung      Adzuna
